# %%
import pandas as pd

# %%
vmm_ts = pd.read_csv('../CSV-data/vmm_ts_values_with_headers.csv')
# Out:
# /tmp/ipykernel_4867/2091845242.py:1: DtypeWarning: Columns (11,12,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   vmm_ts = pd.read_csv('../CSV-data/vmm_ts_values_with_headers.csv')

# %%
print(vmm_ts['Timestamp'])
# Out:
# 0         2025-04-03T11:15:00+00:00
# 1         2025-04-03T11:30:00+00:00
# 2         2025-04-03T11:45:00+00:00
# 3         2025-04-03T12:00:00+00:00
# 4         2025-04-03T12:15:00+00:00
#                     ...
# 591344    2025-04-04T10:15:00+00:00
# 591345    2025-04-04T10:30:00+00:00
# 591346    2025-04-04T10:45:00+00:00
# 591347    2025-04-04T11:00:00+00:00
# 591348    2025-04-04T11:15:00+00:00
# Name: Timestamp, Length: 591349, dtype: object

# %%
vmm_ts['Timestamp'] = vmm_ts['Timestamp'].astype(str).str.replace(' ','T', regex=False)

# %%
vmm_ts.to_csv('../CSV-data/vmm_ts_values_with_headers.csv')
